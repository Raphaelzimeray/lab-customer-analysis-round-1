# %% [markdown]
# # Customer analysis round 1 - 09/05/2023

# %% [markdown]
# Remember the process:
# Case Study
# Get data
# Cleaning/Wrangling/EDA
# Processing Data
# Modeling
# Validation
# Reporting
# Abstract
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 csv files that are provided in the files_for_lab folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# Instructions
# Read the three files into python as dataframes
#
# Show the DataFrame's shape.
#
# Standardize header names.
#
# Rearrange the columns in the dataframe as needed
#
# Correct the values in the column 'customer lifetime value'. They are given as a percent, so divide them by 100 and change dtype to numerical type. (only 2 of the files need this step.)
#
# Concatenate the three dataframes
#
# Which columns are numerical?
#
# Which columns are categorical?
#
# Understand the meaning of all columns
#
# Perform the data cleaning operations mentioned so far in class
#
# Delete the column education and the number of open complaints from the dataframe.
# Check for duplicate rows in the data and remove if any.
# Filter out the data for customers who have an income of 0 or less. (Only show customers who HAVE an income.)

# %%
import pandas as pd

# %% [markdown]
# Read the three files into python as dataframes

# %%
file_1 = pd.read_csv("file1.csv")

# %%
file_2 = pd.read_csv("file2.csv")

# %%
file_3 = pd.read_csv("file3.csv")

# %%
# Show the DataFrame's shape.
file_1.shape
# Out:
# (4008, 11)

# %%
file_1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#Show the DataFrame's shape 
file_2.shape
# Out:
# (996, 11)

# %%
file_2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
#Show the DataFrame's shape
file_3.shape
# Out:
# (7070, 11)

# %%
file_3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
# Standardize header names.
for serie in file_1:
    print (file_1[serie].name)
# Out:
# Customer
# ST
# GENDER
# Education
# Customer Lifetime Value
# Income
# Monthly Premium Auto
# Number of Open Complaints
# Policy Type
# Vehicle Class
# Total Claim Amount

# %%
file_1.columns = file_1.columns.str.lower()
file_1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file_2.columns = file_2.columns.str.lower()
file_2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %%
file_3.columns = file_3.columns.str.lower()
file_3
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %% [markdown]
# Rearrange the columns in the dataframe as needed

# %%
list_header = []

for serie in file_1:
    list_header.append(file_1[serie].name)
    
print (list_header)
# Out:
# ['customer', 'st', 'gender', 'education', 'customer lifetime value', 'income', 'monthly premium auto', 'number of open complaints', 'policy type', 'vehicle class', 'total claim amount']

# %%
file_2.head(1)
# Out:
#   customer       st gender education customer lifetime value  income  \
# 0  GS98873  Arizona      F  Bachelor              323912.47%   16061
#
#    monthly premium auto number of open complaints  total claim amount  \
# 0                    88                    1/0/00               633.6
#
#      policy type  vehicle class
# 0  Personal Auto  Four-Door Car

# %%
file_2 = file_2[['customer',
                 'st',
                 'gender',
                 'education',
                 'customer lifetime value',
                 'income',
                 'monthly premium auto',
                 'number of open complaints',
                 'policy type',
                 'vehicle class',
                 'total claim amount']]
file_2.head(2)
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
#
#    monthly premium auto number of open complaints    policy type  \
# 0                    88                    1/0/00  Personal Auto
# 1                   114                    1/0/00   Special Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6
# 1            SUV               547.2

# %%
file_3.head(1)
# Out:
#   customer       state  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
#
#    total claim amount vehicle class
# 0               499.2  Two-Door Car

# %%
file_3 = file_3.rename(columns = {'state' : 'st'})
file_3.head(1)
# Out:
#   customer          st  customer lifetime value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
#
#    total claim amount vehicle class
# 0               499.2  Two-Door Car

# %%
file_3 = file_3[['customer',
                 'st',
                 'gender',
                 'education',
                 'customer lifetime value',
                 'income',
                 'monthly premium auto',
                 'number of open complaints',
                 'policy type',
                 'vehicle class',
                 'total claim amount']]
file_3.head(2)
# Out:
#   customer          st gender             education  customer lifetime value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
#
#    income  monthly premium auto  number of open complaints    policy type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
#
#   vehicle class  total claim amount
# 0  Two-Door Car          499.200000
# 1  Two-Door Car            3.468912

# %% [markdown]
# Correct the values in the column  'customer lifetime value'. They are given as a percent, so divide them by 100 and change dtype to numerical type. (only 2 of the files need this step.)

# %%
file_1.head(1)
# Out:
#   customer          st gender education customer lifetime value  income  \
# 0  RB50392  Washington    NaN    Master                     NaN     0.0
#
#    monthly premium auto number of open complaints    policy type  \
# 0                1000.0                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934

# %%
file_1['customer lifetime value']
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 4003            NaN
# 4004            NaN
# 4005            NaN
# 4006            NaN
# 4007            NaN
# Name: customer lifetime value, Length: 4008, dtype: object

# %%
file_1['customer lifetime value'] = file_1['customer lifetime value'].str.replace('%',"")
file_1['customer lifetime value']
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: customer lifetime value, Length: 4008, dtype: object

# %%
file_1['customer lifetime value'] = file_1['customer lifetime value'].astype('float')
file_1['customer lifetime value']
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: customer lifetime value, Length: 4008, dtype: float64

# %%
file_1['customer lifetime value'] = file_1['customer lifetime value']/100
file_1['customer lifetime value']
# Out:
# 0              NaN
# 1        6979.5359
# 2       12887.4317
# 3        7645.8618
# 4        5363.0765
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: customer lifetime value, Length: 4008, dtype: float64

# %% [markdown]
# ## do the same thing with file_2

# %%
file_2.head(1)
# Out:
#   customer       st gender education customer lifetime value  income  \
# 0  GS98873  Arizona      F  Bachelor              323912.47%   16061
#
#    monthly premium auto number of open complaints    policy type  \
# 0                    88                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car               633.6

# %%
file_2['customer lifetime value']
# Out:
# 0       323912.47%
# 1       462680.11%
# 2       899704.02%
# 3      2580706.30%
# 4       380812.21%
#           ...
# 991     847141.75%
# 992     543121.91%
# 993     568964.41%
# 994     368672.38%
# 995     399258.39%
# Name: customer lifetime value, Length: 996, dtype: object

# %%
file_2['customer lifetime value'] = file_2['customer lifetime value'].str.replace('%',"")
file_2['customer lifetime value']
# Out:
# 0       323912.47
# 1       462680.11
# 2       899704.02
# 3      2580706.30
# 4       380812.21
#           ...
# 991     847141.75
# 992     543121.91
# 993     568964.41
# 994     368672.38
# 995     399258.39
# Name: customer lifetime value, Length: 996, dtype: object

# %%
file_2['customer lifetime value'] = file_2['customer lifetime value'].astype('float')
file_2['customer lifetime value']
# Out:
# 0       323912.47
# 1       462680.11
# 2       899704.02
# 3      2580706.30
# 4       380812.21
#           ...
# 991     847141.75
# 992     543121.91
# 993     568964.41
# 994     368672.38
# 995     399258.39
# Name: customer lifetime value, Length: 996, dtype: float64

# %%
file_2['customer lifetime value'] = file_2['customer lifetime value']/100
file_2['customer lifetime value']
# Out:
# 0       3239.1247
# 1       4626.8011
# 2       8997.0402
# 3      25807.0630
# 4       3808.1221
#           ...
# 991     8471.4175
# 992     5431.2191
# 993     5689.6441
# 994     3686.7238
# 995     3992.5839
# Name: customer lifetime value, Length: 996, dtype: float64

# %% [markdown]
# Which columns are numerical?
#
# Which columns are categorical?
#
# Understand the meaning of all columns
#
# Perform the data cleaning operations mentioned so far in class
#
# Delete the column education and the number of open complaints from the dataframe.
# Check for duplicate rows in the data and remove if any.
# Filter out the data for customers who have an income of 0 or less. (Only show customers who HAVE an income.)

# %%
file_1.head(1)
# Out:
#   customer          st gender education  customer lifetime value  income  \
# 0  RB50392  Washington    NaN    Master                      NaN     0.0
#
#    monthly premium auto number of open complaints    policy type  \
# 0                1000.0                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934

# %%
#Compter le nombre de valeurs uniques par données
print("Nombre de lignes : " + str(len(file_1.index)))


for serie in file_1:
    print("\n" + file_1[serie].name + " : " + 
          str(len(file_1[serie].unique())) + " Valeur unique")
    print(file_1[serie].value_counts())
    #print("data type : ", file_1[serie].dtype)
# Out:
# Nombre de lignes : 4008
#
# customer : 1072 Valeur unique
# RB50392    1
# HJ15383    1
# AO74776    1
# HQ82233    1
# OL72737    1
#           ..
# RO26085    1
# ES57969    1
# JK55587    1
# RN97635    1
# MY31220    1
# Name: customer, Length: 1071, dtype: int64
#
# st : 9 Valeur unique
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: st, dtype: int64
#
# gender : 6 Valeur unique
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: gender, dtype: int64
#
# education : 7 Valeur unique
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# Name: education, dtype: int64
#
# customer lifetime value : 1028 Valeur unique
# 4458.1134     4
# 2514.5920     4
# 2725.3564     3
# 5780.1822     3
# ...

# %% [markdown]
# # Concatenate the three dataframes

# %%
file_4 = pd.concat([file_1, file_2, file_3])
file_4
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 0                         NaN      0.0                1000.0
# 1                 6979.535900      0.0                  94.0
# 2                12887.431700  48767.0                 108.0
# ...

# %%
file_4.shape
# Out:
# (12074, 11)

# %%
# les 50 dernières lignes du fichier
file_4.tail(50)
# Out:
#      customer          st gender             education  \
# 7020  AL95338  California      F  High School or Below
# 7021  WL28610  California      F  High School or Below
# 7022  AC73173  California      M              Bachelor
# 7023  GV76798  California      F                Master
# 7024  SP29219  California      M               College
# 7025  CI30899  California      F               College
# 7026  MI49191  California      M              Bachelor
# 7027  YP16210  California      F               College
# 7028  CO91673  California      F              Bachelor
# 7029  CC93587  California      M               College
# 7030  MX48796  California      F              Bachelor
# 7031  IC80537  California      M               College
# 7032  AA93585  California      M               College
# 7033  SR41132  California      F  High School or Below
# 7034  IT11766  California      F              Bachelor
# 7035  QO68842  California      F                Doctor
# ...

# %%
# réinilialiser les indices à partir de 0
file_4 = file_4.reset_index()
file_4
# Out:
#        index customer          st gender             education  \
# 0          0  RB50392  Washington    NaN                Master
# 1          1  QZ44356     Arizona      F              Bachelor
# 2          2  AI49188      Nevada      F              Bachelor
# 3          3  WW63253  California      M              Bachelor
# 4          4  GA49547  Washington      M  High School or Below
# ...      ...      ...         ...    ...                   ...
# 12069   7065  LA72316  California      M              Bachelor
# 12070   7066  PK87824  California      F               College
# 12071   7067  TD14365  California      M              Bachelor
# 12072   7068  UP19263  California      M               College
# 12073   7069  Y167826  California      M               College
#
#        customer lifetime value   income  monthly premium auto  \
# 0                          NaN      0.0                1000.0
# 1                  6979.535900      0.0                  94.0
# ...

# %%
file_4.head(1)
# Out:
#    index customer          st gender education  customer lifetime value  \
# 0      0  RB50392  Washington    NaN    Master                      NaN
#
#    income  monthly premium auto number of open complaints    policy type  \
# 0     0.0                1000.0                    1/0/00  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934

# %%
# supprimer la colonne index 
file_4.drop(columns=['index'], inplace= True)
file_4
# Out:
#       customer          st gender             education  \
# 0      RB50392  Washington    NaN                Master
# 1      QZ44356     Arizona      F              Bachelor
# 2      AI49188      Nevada      F              Bachelor
# 3      WW63253  California      M              Bachelor
# 4      GA49547  Washington      M  High School or Below
# ...        ...         ...    ...                   ...
# 12069  LA72316  California      M              Bachelor
# 12070  PK87824  California      F               College
# 12071  TD14365  California      M              Bachelor
# 12072  UP19263  California      M               College
# 12073  Y167826  California      M               College
#
#        customer lifetime value   income  monthly premium auto  \
# 0                          NaN      0.0                1000.0
# 1                  6979.535900      0.0                  94.0
# 2                 12887.431700  48767.0                 108.0
# ...

# %%
# afficher les valeures NaN
file_4.isnull()
# Out:
#        customer     st  gender  education  customer lifetime value  income  \
# 0         False  False    True      False                     True   False
# 1         False  False   False      False                    False   False
# 2         False  False   False      False                    False   False
# 3         False  False   False      False                    False   False
# 4         False  False   False      False                    False   False
# ...         ...    ...     ...        ...                      ...     ...
# 12069     False  False   False      False                    False   False
# 12070     False  False   False      False                    False   False
# 12071     False  False   False      False                    False   False
# 12072     False  False   False      False                    False   False
# 12073     False  False   False      False                    False   False
#
# ...

# %%
# nombre de valeures nulles
file_4.isnull().sum()
# Out:
# customer                     2937
# st                           2937
# gender                       3059
# education                    2937
# customer lifetime value      2944
# income                       2937
# monthly premium auto         2937
# number of open complaints    2937
# policy type                  2937
# vehicle class                2937
# total claim amount           2937
# dtype: int64

# %%
import seaborn as sbn

# %%
# carte de chaleur pour voir plus clairement les valeures nulles et les valeures normales
sbn.heatmap(file_4.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# let's delete theses NaN values

# %%
file_4 = file_4.dropna(how='all')
file_4.isnull().sum()
# Out:
# customer                       0
# st                             0
# gender                       122
# education                      0
# customer lifetime value        7
# income                         0
# monthly premium auto           0
# number of open complaints      0
# policy type                    0
# vehicle class                  0
# total claim amount             0
# dtype: int64

# %%
sbn.heatmap(file_4.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
# supprimer les deux colones éducation et nombre de plaintes
file_4.drop(columns=['education','number of open complaints'], inplace= True)
file_4
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[334], line 2
#       1 # supprimer les deux colones éducation et nombre de plaintes
# ----> 2 file_4.drop(columns=['education','number of open complaints'], inplace= True)
#       3 file_4
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
file_4.head(0)
# Out:
# Empty DataFrame
# Columns: [customer, st, gender, customer lifetime value, income, monthly premium auto, policy type, vehicle class, total claim amount]
# Index: []

# %% [markdown]
# # Check for duplicate rows in the data and remove if any.

# %%
# supprimer les doublons
duplicate = file_4.duplicated()
duplicate
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12069    False
# 12070    False
# 12071    False
# 12072    False
# 12073    False
# Length: 9137, dtype: bool

# %%
# le nombre de ligne similaires est 3
print("le nombre de lignes en double est : ",sum(duplicate))
# Out:
# le nombre de lignes en double est :  3

# %%
file_4 = file_4.drop_duplicates()
file_4
# Out:
#       customer          st gender  customer lifetime value   income  \
# 0      RB50392  Washington    NaN                      NaN      0.0
# 1      QZ44356     Arizona      F              6979.535900      0.0
# 2      AI49188      Nevada      F             12887.431700  48767.0
# 3      WW63253  California      M              7645.861800      0.0
# 4      GA49547  Washington      M              5363.076500  36357.0
# ...        ...         ...    ...                      ...      ...
# 12069  LA72316  California      M             23405.987980  71941.0
# 12070  PK87824  California      F              3096.511217  21604.0
# 12071  TD14365  California      M              8163.890428      0.0
# 12072  UP19263  California      M              7524.442436  21941.0
# 12073  Y167826  California      M              2611.836866      0.0
#
#        monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %%
#on remet les index dans l'ordre 
file_4 = file_4.reset_index()
file_4
# Out:
#       index customer          st gender  customer lifetime value   income  \
# 0         0  RB50392  Washington    NaN                      NaN      0.0
# 1         1  QZ44356     Arizona      F              6979.535900      0.0
# 2         2  AI49188      Nevada      F             12887.431700  48767.0
# 3         3  WW63253  California      M              7645.861800      0.0
# 4         4  GA49547  Washington      M              5363.076500  36357.0
# ...     ...      ...         ...    ...                      ...      ...
# 9129  12069  LA72316  California      M             23405.987980  71941.0
# 9130  12070  PK87824  California      F              3096.511217  21604.0
# 9131  12071  TD14365  California      M              8163.890428      0.0
# 9132  12072  UP19263  California      M              7524.442436  21941.0
# 9133  12073  Y167826  California      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# ...

# %% [markdown]
# # Filter out the data for customers who have an income of 0 or less. (Only show customers who HAVE an income.)

# %%
# afficher les 5 premières lignes de st, et gender
file_4.loc[0:5, ['st', 'gender']]
# Out:
#            st gender
# 0  Washington    NaN
# 1     Arizona      F
# 2      Nevada      F
# 3  California      M
# 4  Washington      M
# 5      Oregon      F

# %%
# afficher de 0 à la fin
file_4.loc[0:, ['st', 'gender']]
# Out:
#               st gender
# 0     Washington    NaN
# 1        Arizona      F
# 2         Nevada      F
# 3     California      M
# 4     Washington      M
# ...          ...    ...
# 9129  California      M
# 9130  California      F
# 9131  California      M
# 9132  California      M
# 9133  California      M
#
# [9134 rows x 2 columns]

# %%
# afficher les 27 premières lignes 
file_4.loc[0:27, ['st', 'gender']]
# Out:
#             st gender
# 0   Washington    NaN
# 1      Arizona      F
# 2       Nevada      F
# 3   California      M
# 4   Washington      M
# 5       Oregon      F
# 6       Oregon      F
# 7      Arizona      M
# 8       Oregon      M
# 9       Oregon      F
# 10  California      M
# 11  California    NaN
# 12  California    NaN
# 13     Arizona    NaN
# 14  California    NaN
# 15      Oregon    NaN
# 16      Nevada    NaN
# 17        Cali    NaN
# 18      Oregon    NaN
# 19  California    NaN
# 20      Oregon    NaN
# 21  Washington      M
# 22     Arizona    NaN
# 23      Nevada    NaN
# 24  California    NaN
# 25      Oregon    NaN
# 26  California    NaN
# 27  Washington      M

# %%
# création d'un filtre
filter_zero_or_less = (file_4['income'] <= 0)
file_4.loc[filter_zero_or_less, ['income']]
# Out:
#       income
# 0        0.0
# 1        0.0
# 3        0.0
# 7        0.0
# 10       0.0
# ...      ...
# 9123     0.0
# 9125     0.0
# 9126     0.0
# 9131     0.0
# 9133     0.0
#
# [2294 rows x 1 columns]
